# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Day8_Ecommerce_Sales_Dataset.csv")

df.head()
# Out:
#    Order_ID  Order_Date      Customer       City Region     Category  \
# 0      1001  2026-02-27     Kabir Ali  Hyderabad  South  Electronics
# 1      1002  2026-01-24  Aditya Verma      Jammu  North       Sports
# 2      1003  2026-04-18    Sara Ahmed    Chennai  South  Electronics
# 3      1004  2026-03-13     Kabir Ali    Lucknow  North  Electronics
# 4      1005  2026-03-30   Priya Menon      Jammu  North  Electronics
#
#                Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# 0  Wireless Headphones         3        1499                 0      4497.00
# 1        Running Shoes         1        2799                 0      2799.00
# 2           Power Bank         2        1199                15      2038.30
# 3  Mechanical Keyboard         4        2499                 5      9496.20
# 4          Smart Watch         1        3299                 5      3134.05
#
#    Rating    Payment_Method
# 0     3.8  Cash on Delivery
# 1     4.1  Cash on Delivery
# 2     4.6  Cash on Delivery
# 3     4.1        Debit Card
# 4     4.2               UPI

# %%
print("Shape of dataset:", df.shape)

print("Columns:")
print(df.columns.tolist())

print("Data Types:")
print(df.dtypes)
# Out:
# Shape of dataset: (100, 13)
# Columns:
# ['Order_ID', 'Order_Date', 'Customer', 'City', 'Region', 'Category', 'Product', 'Quantity', 'Unit_Price', 'Discount_Percent', 'Total_Sales', 'Rating', 'Payment_Method']
# Data Types:
# Order_ID              int64
# Order_Date           object
# Customer             object
# City                 object
# Region               object
# Category             object
# Product              object
# Quantity              int64
# Unit_Price            int64
# Discount_Percent      int64
# Total_Sales         float64
# Rating              float64
# Payment_Method       object
# dtype: object

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          100 non-null    int64
#  1   Order_Date        100 non-null    object
#  2   Customer          100 non-null    object
#  3   City              100 non-null    object
#  4   Region            100 non-null    object
#  5   Category          100 non-null    object
#  6   Product           100 non-null    object
#  7   Quantity          100 non-null    int64
#  8   Unit_Price        100 non-null    int64
#  9   Discount_Percent  100 non-null    int64
#  10  Total_Sales       100 non-null    float64
#  11  Rating            100 non-null    float64
#  12  Payment_Method    100 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 10.3+ KB
#            Order_ID  Order_Date      Customer     City Region Category  \
# count    100.000000         100           100      100    100      100
# unique          NaN          78            25       15      4        5
# top             NaN  2026-03-13  Aditya Verma  Chennai  North   Sports
# freq            NaN           3             9       10     38       25
# mean    1050.500000         NaN           NaN      NaN    NaN      NaN
# std       29.011492         NaN           NaN      NaN    NaN      NaN
# min     1001.000000         NaN           NaN      NaN    NaN      NaN
# 25%     1025.750000         NaN           NaN      NaN    NaN      NaN
# 50%     1050.500000         NaN           NaN      NaN    NaN      NaN
# 75%     1075.250000         NaN           NaN      NaN    NaN      NaN
# max     1100.000000         NaN           NaN      NaN    NaN      NaN
#
#                     Product    Quantity   Unit_Price  Discount_Percent  \
# count                   100  100.000000   100.000000        100.000000
# unique                   23         NaN          NaN               NaN
# top     Wireless Headphones         NaN          NaN               NaN
# freq                      7         NaN          NaN               NaN
# mean                    NaN    2.940000  1647.000000          6.500000
# std                     NaN    1.391315   970.054669          6.092718
# min                     NaN    1.000000   499.000000          0.000000
# 25%                     NaN    2.000000   799.000000          0.000000
# 50%                     NaN    3.000000  1499.000000          5.000000
# 75%                     NaN    4.000000  2499.000000         11.250000
# max                     NaN    5.000000  3499.000000         15.000000
#
#          Total_Sales      Rating Payment_Method
# count     100.000000  100.000000            100
# unique           NaN         NaN              5
# top              NaN         NaN            UPI
# freq             NaN         NaN             26
# mean     4472.629500    4.322000            NaN
# std      3324.306691    0.414285            NaN
# min       449.100000    3.500000            NaN
# 25%      1948.050000    4.100000            NaN
# 50%      3228.300000    4.300000            NaN
# 75%      6427.562500    4.700000            NaN
# max     13995.000000    5.000000            NaN

# %%
#single column
df["Customer"]
# Out:
# 0        Kabir Ali
# 1     Aditya Verma
# 2       Sara Ahmed
# 3        Kabir Ali
# 4      Priya Menon
#           ...
# 95    Aditya Verma
# 96      Arjun Nair
# 97       Yusuf Dar
# 98     Hiba Sheikh
# 99       Kabir Ali
# Name: Customer, Length: 100, dtype: object

# %%
#multiple columns
df[["Customer","City","Category"]]
# Out:
#         Customer       City        Category
# 0      Kabir Ali  Hyderabad     Electronics
# 1   Aditya Verma      Jammu          Sports
# 2     Sara Ahmed    Chennai     Electronics
# 3      Kabir Ali    Lucknow     Electronics
# 4    Priya Menon      Jammu     Electronics
# ..           ...        ...             ...
# 95  Aditya Verma      Kochi          Sports
# 96    Arjun Nair     Mumbai        Clothing
# 97     Yusuf Dar  Bengaluru  Home & Kitchen
# 98   Hiba Sheikh  Ahmedabad           Books
# 99     Kabir Ali       Pune           Books
#
# [100 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer            0
# City                0
# Region              0
# Category            0
# Product             0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Total_Sales         0
# Rating              0
# Payment_Method      0
# dtype: int64

# %%
#select specific columns and rows
df.loc[0:4, ["Order_ID", "Product", "Total_Sales"]]
# Out:
#    Order_ID              Product  Total_Sales
# 0      1001  Wireless Headphones      4497.00
# 1      1002        Running Shoes      2799.00
# 2      1003           Power Bank      2038.30
# 3      1004  Mechanical Keyboard      9496.20
# 4      1005          Smart Watch      3134.05

# %%
high_sales = df[df["Total_Sales"] > 5000]

high_sales
# Out:
#     Order_ID  Order_Date       Customer         City Region        Category  \
# 3       1004  2026-03-13      Kabir Ali      Lucknow  North     Electronics
# 7       1008  2026-04-27     Aman Kumar        Jammu  North        Clothing
# 9       1010  2026-03-11     Aman Kumar        Kochi  South        Clothing
# 10      1011  2026-03-22      Rahul Das    Hyderabad  South  Home & Kitchen
# 12      1013  2026-03-09    Maryam Khan      Lucknow  North        Clothing
# 13      1014  2026-02-05      Dev Patel       Jaipur  North          Sports
# 16      1017  2026-03-17     Sana Malik    Hyderabad  South          Sports
# 18      1019  2026-05-19   Reyansh Jain      Chennai  South        Clothing
# 27      1028  2026-04-19     Sana Malik   Chandigarh  North     Electronics
# 28      1029  2026-01-28     Sara Ahmed    Hyderabad  South     Electronics
# 32      1033  2026-06-28    Maryam Khan         Pune   West  Home & Kitchen
# 37      1038  2026-03-08   Aditya Verma         Pune   West          Sports
# 38      1039  2026-04-28  Vivaan Kapoor   Chandigarh  North  Home & Kitchen
# 27  Wireless Headphones         4        1499                 5      5696.20
# 28  Wireless Headphones         4        1499                 5      5696.20
# 36           Power Bank         2        1199                15      2038.30
# 46       Wireless Mouse         5         899                15      3820.75
# 50          Smart Watch         2        3299                 0      6598.00
# 51  Mechanical Keyboard         4        2499                 5      9496.20
# 61  Mechanical Keyboard         3        2499                 0      7497.00
# 65          Smart Watch         2        3299                10      5938.20
# 68       Wireless Mouse         2         899                 5      1708.10
# 75  Wireless Headphones         4        1499                 0      5996.00
# 83       Wireless Mouse         5         899                10      4045.50
# 91  Wireless Headphones         3        1499                 0      4497.00
# 94           Power Bank         2        1199                 0      2398.00
#
#     Rating    Payment_Method
# 0      3.8  Cash on Delivery
# 2      4.6  Cash on Delivery
# 3      4.1        Debit Card
# 4      4.2               UPI
# 14     4.8               UPI
# 25     4.2       Net Banking
# 27     4.6               UPI
# 28     4.1       Credit Card
# 36     4.8               UPI
# 46     4.0               UPI
# 50     4.2       Credit Card
# 51     4.2        Debit Card
# 61     3.5               UPI
# 65     4.7  Cash on Delivery
# 68     4.7               UPI
# 75     3.5        Debit Card
# 83     3.8  Cash on Delivery
# 91     4.1        Debit Card
# 94     4.6        Debit Card

# %%
df.sort_values(by="Total_Sales", ascending=False)
# Out:
#     Order_ID  Order_Date      Customer        City Region        Category  \
# 48      1049  2026-03-02  Ishita Gupta      Mumbai   West          Sports
# 52      1053  2026-01-08  Ananya Singh   Hyderabad  South          Sports
# 84      1085  2026-01-28    Sana Malik   Hyderabad  South  Home & Kitchen
# 89      1090  2026-05-13  Aditya Verma     Lucknow  North          Sports
# 12      1013  2026-03-09   Maryam Khan     Lucknow  North        Clothing
# ..       ...         ...           ...         ...    ...             ...
# 60      1061  2026-05-12    Alina Shah   Bengaluru  South           Books
# 96      1097  2026-02-02    Arjun Nair      Mumbai   West        Clothing
# 73      1074  2026-03-28    Alina Shah     Lucknow  North           Books
# 5       1006  2026-01-21     Manya Rao       Kochi  South           Books
# 62      1063  2026-04-17    Aman Kumar  Chandigarh  North           Books
#
#                Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# 48       Running Shoes         5        2799                 0     13995.00
# 52       Running Shoes         5        2799                 5     13295.25
# 84        Coffee Maker         4        3499                10     12596.40
# 89         Cricket Bat         5        2499                 0     12495.00
# 12              Jacket         5        2499                15     10620.75
# ..                 ...       ...         ...               ...          ...
# 60  Python Programming         1         749                 5       711.55
# 96             T-Shirt         1         799                15       679.15
# 73       Atomic Habits         1         599                10       539.10
# 5        The Alchemist         1         499                10       449.10
# 62       The Alchemist         1         499                10       449.10
#
#     Rating    Payment_Method
# 48     4.0       Net Banking
# 52     4.2       Credit Card
# 84     4.3       Net Banking
# 89     3.8       Credit Card
# 12     4.8       Net Banking
# ..     ...               ...
# 60     5.0  Cash on Delivery
# 96     3.5               UPI
# 73     5.0       Net Banking
# 5      4.2  Cash on Delivery
# 62     4.8       Credit Card
#
# [100 rows x 13 columns]

# %%
df.sort_values(by="Total_Sales", ascending=False)
# Out:
#     Order_ID  Order_Date      Customer        City Region        Category  \
# 48      1049  2026-03-02  Ishita Gupta      Mumbai   West          Sports
# 52      1053  2026-01-08  Ananya Singh   Hyderabad  South          Sports
# 84      1085  2026-01-28    Sana Malik   Hyderabad  South  Home & Kitchen
# 89      1090  2026-05-13  Aditya Verma     Lucknow  North          Sports
# 12      1013  2026-03-09   Maryam Khan     Lucknow  North        Clothing
# ..       ...         ...           ...         ...    ...             ...
# 60      1061  2026-05-12    Alina Shah   Bengaluru  South           Books
# 96      1097  2026-02-02    Arjun Nair      Mumbai   West        Clothing
# 73      1074  2026-03-28    Alina Shah     Lucknow  North           Books
# 5       1006  2026-01-21     Manya Rao       Kochi  South           Books
# 62      1063  2026-04-17    Aman Kumar  Chandigarh  North           Books
#
#                Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# 48       Running Shoes         5        2799                 0     13995.00
# 52       Running Shoes         5        2799                 5     13295.25
# 84        Coffee Maker         4        3499                10     12596.40
# 89         Cricket Bat         5        2499                 0     12495.00
# 12              Jacket         5        2499                15     10620.75
# ..                 ...       ...         ...               ...          ...
# 60  Python Programming         1         749                 5       711.55
# 96             T-Shirt         1         799                15       679.15
# 73       Atomic Habits         1         599                10       539.10
# 5        The Alchemist         1         499                10       449.10
# 62       The Alchemist         1         499                10       449.10
#
#     Rating    Payment_Method
# 48     4.0       Net Banking
# 52     4.2       Credit Card
# 84     4.3       Net Banking
# 89     3.8       Credit Card
# 12     4.8       Net Banking
# ..     ...               ...
# 60     5.0  Cash on Delivery
# 96     3.5               UPI
# 73     5.0       Net Banking
# 5      4.2  Cash on Delivery
# 62     4.8       Credit Card
#
# [100 rows x 13 columns]

# %%
total_sales = df["Total_Sales"].sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 447262.95000000007

# %%
average_sales = df["Total_Sales"].mean()

print("Average Sales:", average_sales)
# Out:
# Average Sales: 4472.629500000001

# %%
total_quantity = df["Quantity"].sum()

print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 294

# %%
category_sales = (
    df.groupby("Category")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Sports            136026.45
# Home & Kitchen    113329.90
# Electronics        92086.00
# Clothing           69028.20
# Books              36792.40
# Name: Total_Sales, dtype: float64

# %%
category_average = (
    df.groupby("Category")["Total_Sales"]
    .mean()
    .sort_values(ascending=False)
)

category_average
# Out:
# Category
# Sports            5441.058000
# Home & Kitchen    5396.661905
# Clothing          4930.585714
# Electronics       4846.631579
# Books             1752.019048
# Name: Total_Sales, dtype: float64

# %%
city_sales = (
    df.groupby("City")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

city_sales
# Out:
# City
# Hyderabad      59076.45
# Chennai        47493.20
# Lucknow        46194.65
# Pune           41908.55
# Mumbai         41457.80
# Kochi          37257.50
# Chandigarh     34539.65
# Delhi          30882.80
# Jaipur         25534.00
# Kolkata        20169.00
# Jammu          16059.75
# Ahmedabad      14788.70
# Bengaluru      13524.30
# Srinagar       11778.60
# Bhubaneswar     6598.00
# Name: Total_Sales, dtype: float64

# %%
city_sales.head(5)
# Out:
# City
# Hyderabad    59076.45
# Chennai      47493.20
# Lucknow      46194.65
# Pune         41908.55
# Mumbai       41457.80
# Name: Total_Sales, dtype: float64

# %%
product_sales = (
    df.groupby("Product")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

product_sales
# Out:
# Product
# Coffee Maker               51610.25
# Jacket                     47106.15
# Cricket Bat                41483.40
# Running Shoes              41285.25
# Wireless Headphones        33877.40
# Dumbbell Set               30184.90
# Mechanical Keyboard        26489.40
# Electric Kettle            26382.40
# Mixer Grinder              25341.55
# Smart Watch                15670.25
# Yoga Mat                   12765.80
# Atomic Habits              11590.65
# Football                   10307.10
# Water Bottle                9995.70
# Wireless Mouse              9574.35
# T-Shirt                     7790.25
# Hoodie                      7675.20
# Python Programming          7527.45
# The Alchemist               7485.00
# Power Bank                  6474.60
# Jeans                       6456.60
# Machine Learning Basics     5694.30
# Data Science Handbook       4495.00
# Name: Total_Sales, dtype: float64

# %%
product_sales.head(10)
# Out:
# Product
# Coffee Maker           51610.25
# Jacket                 47106.15
# Cricket Bat            41483.40
# Running Shoes          41285.25
# Wireless Headphones    33877.40
# Dumbbell Set           30184.90
# Mechanical Keyboard    26489.40
# Electric Kettle        26382.40
# Mixer Grinder          25341.55
# Smart Watch            15670.25
# Name: Total_Sales, dtype: float64

# %%
payment_sales = (
    df.groupby("Payment_Method")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

payment_sales
# Out:
# Payment_Method
# Credit Card         106540.25
# Debit Card           98064.90
# Net Banking          96371.25
# UPI                  96163.25
# Cash on Delivery     50123.30
# Name: Total_Sales, dtype: float64

# %%
payment_analysis = df.groupby("Payment_Method").agg(
    Total_Sales=("Total_Sales", "sum"),
    Average_Sales=("Total_Sales", "mean"),
    Total_Quantity=("Quantity", "sum"),
    Number_of_Orders=("Order_ID", "count")
).sort_values("Total_Sales", ascending=False)

payment_analysis
# Out:
#                   Total_Sales  Average_Sales  Total_Quantity  Number_of_Orders
# Payment_Method
# Credit Card         106540.25    4842.738636              65                22
# Debit Card           98064.90    4903.245000              64                20
# Net Banking          96371.25    5668.897059              63                17
# UPI                  96163.25    3698.586538              70                26
# Cash on Delivery     50123.30    3341.553333              32                15

# %%
above_average = df[df["Total_Sales"] > df["Total_Sales"].mean()]

above_average
# Out:
#     Order_ID  Order_Date       Customer         City Region        Category  \
# 0       1001  2026-02-27      Kabir Ali    Hyderabad  South     Electronics
# 3       1004  2026-03-13      Kabir Ali      Lucknow  North     Electronics
# 7       1008  2026-04-27     Aman Kumar        Jammu  North        Clothing
# 8       1009  2026-06-05     Aman Kumar       Mumbai   West  Home & Kitchen
# 9       1010  2026-03-11     Aman Kumar        Kochi  South        Clothing
# 10      1011  2026-03-22      Rahul Das    Hyderabad  South  Home & Kitchen
# 11      1012  2026-04-12     Aman Kumar   Chandigarh  North          Sports
# 12      1013  2026-03-09    Maryam Khan      Lucknow  North        Clothing
# 13      1014  2026-02-05      Dev Patel       Jaipur  North          Sports
# 47           Coffee Maker         3        3499                 0
# 48          Running Shoes         5        2799                 0
# 50            Smart Watch         2        3299                 0
# 51    Mechanical Keyboard         4        2499                 5
# 52          Running Shoes         5        2799                 5
# 56           Coffee Maker         3        3499                15
# 58            Cricket Bat         4        2499                15
# 59           Dumbbell Set         3        1999                10
# 61    Mechanical Keyboard         3        2499                 0
# 65            Smart Watch         2        3299                10
# 69                 Jacket         4        2499                 0
# 75    Wireless Headphones         4        1499                 0
# 76        Electric Kettle         4        1499                 5
# 79                 Jacket         4        2499                 0
# 80        Electric Kettle         5        1499                15
# 84           Coffee Maker         4        3499                10
# 89            Cricket Bat         5        2499                 0
# 91    Wireless Headphones         3        1499                 0
# 92            Cricket Bat         4        2499                15
# 93          Mixer Grinder         3        2999                 5
# 95           Dumbbell Set         5        1999                 5
# 97        Electric Kettle         4        1499                 0
# 99  Data Science Handbook         5         899                 0
#
#     Total_Sales  Rating    Payment_Method
# 0       4497.00     3.8  Cash on Delivery
# 3       9496.20     4.1        Debit Card
# 7       6076.20     4.3       Credit Card
# 8       4497.00     4.0  Cash on Delivery
# 9       8996.40     4.7       Credit Card
# 10      6998.00     4.2               UPI
# 11      4498.20     4.6       Credit Card
# 12     10620.75     4.8       Net Banking
# 13      8397.00     4.6               UPI
# 16      7497.00     4.0       Net Banking
# 18      7497.00     4.7               UPI
# 25      4497.00     4.2       Net Banking
# 27      5696.20     4.6               UPI
# 28      5696.20     4.1       Credit Card
# 32      8097.30     4.7       Net Banking
# 37      9495.25     5.0        Debit Card
# 38      5698.10     3.8               UPI
# 40      6648.10     4.6  Cash on Delivery
# 47     10497.00     5.0               UPI
# 48     13995.00     4.0       Net Banking
# 50      6598.00     4.2       Credit Card
# 51      9496.20     4.2        Debit Card
# 52     13295.25     4.2       Credit Card
# 56      8922.45     4.5        Debit Card
# 58      8496.60     4.2       Credit Card
# 59      5397.30     5.0       Credit Card
# 61      7497.00     3.5               UPI
# 65      5938.20     4.7  Cash on Delivery
# 69      9996.00     3.8       Net Banking
# 75      5996.00     3.5        Debit Card
# 76      5696.20     4.5        Debit Card
# 79      9996.00     4.6        Debit Card
# 80      6370.75     4.0        Debit Card
# 84     12596.40     4.3       Net Banking
# 89     12495.00     3.8       Credit Card
# 91      4497.00     4.1        Debit Card
# 92      8496.60     4.5  Cash on Delivery
# 93      8547.15     3.8       Credit Card
# 95      9495.25     4.2       Credit Card
# 97      5996.00     4.2       Net Banking
# 99      4495.00     4.8        Debit Card

# %%
summary = pd.Series({
    "Total Sales": df["Total_Sales"].sum(),
    "Average Sales": df["Total_Sales"].mean(),
    "Highest Sale": df["Total_Sales"].max(),
    "Lowest Sale": df["Total_Sales"].min(),
    "Total Quantity Sold": df["Quantity"].sum(),
    "Number of Orders": df["Order_ID"].nunique(),
    "Average Rating": df["Rating"].mean()
})

summary
# Out:
# Total Sales            447262.9500
# Average Sales            4472.6295
# Highest Sale            13995.0000
# Lowest Sale               449.1000
# Total Quantity Sold       294.0000
# Number of Orders          100.0000
# Average Rating              4.3220
# dtype: float64
